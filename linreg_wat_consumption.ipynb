# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
import math
import numpy as np
import calendar
import datetime as dt
import altair as alt
# %matplotlib inline

# %%
dat2= pd.read_csv('water_consum_floodplain.csv')

# %%
dat2
# Out:
#         Year  discharge  income  wat_balance
# 0   Apr-2013      31.72   27.99        -3.73
# 1   May-2013      62.15   52.76        -9.39
# 2   Jun-2013      37.59   36.03        -1.56
# 3   Jul-2013      17.82   16.15        -1.67
# 4   Aug-2013      16.05   13.34        -2.71
# 5   Sep-2013      14.53   12.62        -1.91
# 6   Oct-2013      15.81   13.18        -2.63
# 7   Nov-2013      18.30   14.41        -3.89
# 8   Dec-2013      21.60   17.20        -4.40
# 9   Jan-2014      21.28   16.45        -4.83
# 10  Feb-2014      19.39   15.92        -3.47
# 11  Mar-2014      22.23   21.48        -0.75
# 12  Apr-2014      27.63   18.69        -8.94
# 13  May-2014      53.92   42.85       -11.07
# 14  Jun-2014      18.40   18.04        -0.36
# 15  Jul-2014      16.27   13.74        -2.53
# 16  Aug-2014      15.62   12.72        -2.90
# 17  Sep-2014      18.58   14.02        -4.56
# 18  Oct-2014      15.33   13.28        -2.05
# 19  Nov-2014      14.48   12.03        -2.45
# ...

# %%
model = LinearRegression()

# %%
X = pd.DataFrame(dat2.discharge)
Y = pd.DataFrame(dat2.income)

# %%
model.fit(X,Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
model.coef_
# Out:
# array([[0.81476837]])

# %%
model.intercept_
# Out:
# array([0.51559464])

# %%
plt.scatter(dat2.discharge, dat2.income)
plt.plot(X, model.predict(X))

# %%
model.score(X, Y)
# Out:
# 0.9318787632998463

# %%
dat3= pd.read_csv('volzhsk_discharge_till2021.csv')

# %%
Xn = pd.DataFrame(dat3.dichargeR)

# %%
model.predict(Xn)
# Out:
# array([[15.16512991],
#        [14.32591849],
#        [16.56653151],
#        [20.94183765],
#        [52.5792934 ],
#        [30.28723083],
#        [36.86241157],
#        [22.40027303],
#        [16.70504213],
#        [15.26290212],
#        [15.60510483],
#        [21.52847087],
#        [18.47308949],
#        [16.33839636],
#        [20.67296408],
#        [41.69398799],
#        [45.93893119],
#        [25.0075318 ],
#        [21.68327686],
#        [14.06519261],
#        [13.59262696],
#        [13.78817137],
#        [13.88594357],
#        [15.42585579],
#        [14.44813375],
#        [13.3237534 ],
#        [15.36067432],
#        [19.43451616],
#        [33.57889504],
#        [13.47855939],
#        [12.80230164],
#        [15.65399093],
#        [16.66430371],
#        [16.18359037],
#        [29.92058507],
#        [18.68492926],
#        [18.22051129],
#        [19.19823334],
#        [25.36602989],
#        [44.49679118],
#        [44.71677864],
# ...

# %%
dat3['income'] = model.predict(Xn)

# %%
dat3['balance'] = dat3.income - dat3.dichargeR

# %%
plt.figure(figsize=(20,10))
dat3.plot()

# %%
dat3
# Out:
#     Unnamed: 0        date  dichargeR
# 0            0  2017-01-31      17.98
# 1            1  2017-02-28      16.95
# 2            2  2017-03-31      19.70
# 3            3  2017-04-30      25.07
# 4            4  2017-05-31      63.90
# 5            5  2017-06-30      36.54
# 6            6  2017-07-31      44.61
# 7            7  2017-08-31      26.86
# 8            8  2017-09-30      19.87
# 9            9  2017-10-31      18.10
# 10          10  2017-11-30      18.52
# 11          11  2017-12-31      25.79
# 12          12  2018-01-31      22.04
# 13          13  2018-02-28      19.42
# 14          14  2018-03-31      24.74
# 15          15  2018-04-30      50.54
# 16          16  2018-05-31      55.75
# 17          17  2018-06-30      30.06
# 18          18  2018-07-31      25.98
# 19          19  2018-08-31      16.63
# 20          20  2018-09-30      16.05
# 21          21  2018-10-31      16.29
# 22          22  2018-11-30      16.41
# 23          23  2018-12-31      18.30
# ...
